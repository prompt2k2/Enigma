# %%
import pandas as pd

# %% [markdown]
# #### Down the Data from stored Location

# %%
dfraw=pd.read_csv('C://Users/Joshy/Downloads/Toronto_Neighborhood.csv')
#dfraw['Borough']
dfraw
# Out:
#     PostCode                                            Borough
# 0        M1A                                       Not assigned
# 1        M2A                                       Not assigned
# 2        M3A                              North York(Parkwoods)
# 3        M4A                       North York(Victoria Village)
# 4        M5A       Downtown Toronto(Regent Park / Harbourfront)
# ..       ...                                                ...
# 175      M5Z                                       Not assigned
# 176      M6Z                                       Not assigned
# 177      M7Z                                       Not assigned
# 178      M8Z  Etobicoke(Mimico NW / The Queensway West / Sou...
# 179      M9Z                                       Not assigned
#
# [180 rows x 2 columns]

# %% [markdown]
# #### Create a new column from the dataframe, split the Borough column and assign the output to Neighborhood column

# %%
dfraw['Neigborhood']=dfraw['Borough']
dfraw['Borough']=dfraw['Borough'].str.split('(',  expand=True)
dfraw
# Out:
#     PostCode           Borough  \
# 0        M1A      Not assigned
# 1        M2A      Not assigned
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# ..       ...               ...
# 175      M5Z      Not assigned
# 176      M6Z      Not assigned
# 177      M7Z      Not assigned
# 178      M8Z         Etobicoke
# 179      M9Z      Not assigned
#
#                                            Neigborhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                North York(Parkwoods)
# 3                         North York(Victoria Village)
# 4         Downtown Toronto(Regent Park / Harbourfront)
# ..                                                 ...
# 175                                       Not assigned
# 176                                       Not assigned
# 177                                       Not assigned
# ...

# %% [markdown]
# ### Split the Neighborshood column

# %%
dftry=dfraw['Neigborhood'].str.split('(',  expand=True)
dftry
# Out:
#                     0                                                  1     2
# 0        Not assigned                                               None  None
# 1        Not assigned                                               None  None
# 2          North York                                         Parkwoods)  None
# 3          North York                                  Victoria Village)  None
# 4    Downtown Toronto                        Regent Park / Harbourfront)  None
# ..                ...                                                ...   ...
# 175      Not assigned                                               None  None
# 176      Not assigned                                               None  None
# 177      Not assigned                                               None  None
# 178         Etobicoke  Mimico NW / The Queensway West / South of Bloo...  None
# 179      Not assigned                                               None  None
#
# [180 rows x 3 columns]

# %% [markdown]
# ### Assign the relevant column to the working dataframe and drop irrelevant columns

# %%
dfraw['Neighborhood']=dftry[1]
dfraw.drop(['Neigborhood'],axis=1, inplace=True)
dfraw
# Out:
#     PostCode           Borough  \
# 0        M1A      Not assigned
# 1        M2A      Not assigned
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# ..       ...               ...
# 175      M5Z      Not assigned
# 176      M6Z      Not assigned
# 177      M7Z      Not assigned
# 178      M8Z         Etobicoke
# 179      M9Z      Not assigned
#
#                                           Neighborhood
# 0                                                 None
# 1                                                 None
# 2                                           Parkwoods)
# 3                                    Victoria Village)
# 4                          Regent Park / Harbourfront)
# ..                                                 ...
# 175                                               None
# 176                                               None
# 177                                               None
# ...

# %% [markdown]
# ##### create a new df for a table without 'Not Assigned' in label

# %%
df=dfraw[dfraw.Borough !='Not assigned'] 
df
# Out:
#     PostCode                                            Borough  \
# 2        M3A                                         North York
# 3        M4A                                         North York
# 4        M5A                                   Downtown Toronto
# 5        M6A                                         North York
# 6        M7A       Queen's Park / Ontario Provincial Government
# ..       ...                                                ...
# 160      M8X                                          Etobicoke
# 165      M4Y                                   Downtown Toronto
# 168      M7Y  East TorontoBusiness reply mail Processing Cen...
# 169      M8Y                                          Etobicoke
# 178      M8Z                                          Etobicoke
#
#                                           Neighborhood
# 2                                           Parkwoods)
# 3                                    Victoria Village)
# ...

# %% [markdown]
# ### cleaning the neighboor column to remove the closing parenthesis

# %%
dftry=df['Neighborhood'].str.split(')',  expand=True)  
dftry
# Out:
#                                                      0     1
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                           Regent Park / Harbourfront
# 5                    Lawrence Manor / Lawrence Heights
# 6                                                 None  None
# ..                                                 ...   ...
# 160    The Kingsway / Montgomery Road / Old Mill North
# 165                               Church and Wellesley
# 168                                     Enclave of M4L
# 169  Old Mill South / King's Mill Park / Sunnylea /...
# 178  Mimico NW / The Queensway West / South of Bloo...
#
# [103 rows x 2 columns]

# %%
df['Neighborhood']=dftry[0]
df
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     PostCode                                            Borough  \
# 2        M3A                                         North York
# 3        M4A                                         North York
# 4        M5A                                   Downtown Toronto
# 5        M6A                                         North York
# 6        M7A       Queen's Park / Ontario Provincial Government
# ..       ...                                                ...
# 160      M8X                                          Etobicoke
# ...

# %%
df
# Out:
#     PostCode                                            Borough  \
# 2        M3A                                         North York
# 3        M4A                                         North York
# 4        M5A                                   Downtown Toronto
# 5        M6A                                         North York
# 6        M7A       Queen's Park / Ontario Provincial Government
# ..       ...                                                ...
# 160      M8X                                          Etobicoke
# 165      M4Y                                   Downtown Toronto
# 168      M7Y  East TorontoBusiness reply mail Processing Cen...
# 169      M8Y                                          Etobicoke
# 178      M8Z                                          Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# ...

# %% [markdown]
# ###### Replace the None values in Neighborhood Columns with Borough Column values

# %%
   
df['Neighborhood']=df['Neighborhood'].fillna(df['Borough'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#     PostCode                                            Borough  \
# 2        M3A                                         North York
# 3        M4A                                         North York
# 4        M5A                                   Downtown Toronto
# 5        M6A                                         North York
# 6        M7A       Queen's Park / Ontario Provincial Government
# ..       ...                                                ...
# 160      M8X                                          Etobicoke
# 165      M4Y                                   Downtown Toronto
# 168      M7Y  East TorontoBusiness reply mail Processing Cen...
# 169      M8Y                                          Etobicoke
# 178      M8Z                                          Etobicoke
#
#                                           Neighborhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# ...

# %% [markdown]
# ### Check shape of the working Dataframe

# %%
df.shape
# Out:
# (103, 3)
